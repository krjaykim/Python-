# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=5
b=6

# %%
a
# Out:
# 5

# %%
b
# Out:
# 6

# %%
print(2b)
# Out:
#   File "C:\Users\SMHRD\AppData\Local\Temp/ipykernel_16132/3152098231.py", line 1
#     print(2b)
#            ^
# SyntaxError: invalid syntax

# %%
#문자열 사용하기
str1 = 'str1'
str2 = "str2"
str3 = '''str3'''

print(str1)
print(str2)
print(str3)
# Out:
# str1
# str2
# str3

# %%
s="My name is JK"
s
# Out:
# 'My name is JK'

# %%
s[0]
# Out:
# 'M'

# %%
a=int(input("정수입력>>"))
b=int(input("정수입력>>"))
print(f'b:{b}') if a<b else print(f'a:{a}')
# Out:
# 정수입력>>10
# 정수입력>>3
# a:10

# %%
a=int(input("정수입력>>"))
print(f'{a}는 짝수입니다.') if a%2==0 else print(f'{a}는 홀수입니다.')
# Out:
# 정수입력>>2
# 2는 짝수입니다.

# %%
###조건문

- 상황에 따라 실행 흐름을 다르게하느 문법
- if,elif,else
# Out:
#   File "C:\Users\SMHRD\AppData\Local\Temp/ipykernel_16132/2076083158.py", line 2
#     - 상황에 따라 실행 흐름을 다르게하느 문법
#           ^
# SyntaxError: invalid syntax

# %%
if 조건식 :
    실행문장

# %%
if  True:
    print("실행문장 실행")
# Out:
# 실행문장 실행

# %%
if False:
    print("실행문장 실행")
print("ddd")
# Out:
# ddd

# %%
money=int(input("얼마?"))
if money>=10000:
    print("택시를 탄다")
else: 
    print("버스를 탄다")
# Out:
# 얼마?10000
# 택시를 탄다

# %%
a=()
b=(1,2,3)
c=('My','name','is')
d=(1,2,'My','name')

# %%
ㅁ
